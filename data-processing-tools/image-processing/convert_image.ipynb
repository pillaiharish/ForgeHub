# %%
! pip install pillow
! pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 3.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from PIL import Image

# Load the WEBP image file
input_path = "/Users/harishkumarpillai/Downloads/llms3.webp"
output_path = "/Users/harishkumarpillai/Downloads/llms3.png"

# Open the image
img = Image.open(input_path)
# Save the image as PNG
img.save(output_path, "PNG")
output_path
# Out:
# '/Users/harishkumarpillai/Downloads/llms3.png'

# %%
from docx import Document

# Create a new Document
doc = Document()

# Function to add horizontal line (simplified approach)
def add_horizontal_line(doc):
    p = doc.add_paragraph()
    run = p.add_run()
    run.add_break()
    run.add_picture('/mnt/data/line.jpg', width=docx.shared.Inches(6))
    run.add_break()

# Add Header
doc.add_heading('Mirajkumar Thakar', level=1)
doc.add_paragraph('Telco Cloud DC Fabric Architect')
doc.add_paragraph('Email: thakar201@gmail.com')
doc.add_paragraph('LinkedIn: linkedin.com/in/mirajkumar-thakar')

# Add a horizontal line
add_horizontal_line(doc)

# Add Professional Summary
doc.add_heading('Professional Summary', level=2)
doc.add_paragraph(
    'Experienced Network and Cloud Engineer with over 9 years of expertise in designing, deploying, '
    'and managing complex networking and cloud infrastructures. Proficient in OpenStack, OpenShift, '
    'and multi-vendor environments. Strong background in automation using Ansible and scripting. '
    'Proven ability to lead large-scale telco cloud projects, delivering scalable and secure solutions. '
    'Certified in advanced data center and firewall technologies.'
)

# Add a horizontal line
add_horizontal_line(doc)

# Add Technical Skills
doc.add_heading('Technical Skills', level=2)
skills = doc.add_paragraph()
skills.add_run('Cloud Computing: ').bold = True
skills.add_run('Red Hat OpenStack, OpenShift, GCP\n')
skills.add_run('Virtualization: ').bold = True
skills.add_run('VMware ESXi, vSphere\n')
skills.add_run('Networking: ').bold = True
skills.add_run('BGP, OSPF, EIGRP, VxLAN, MP-BGP, EVPN, L2VPN, L3VPN\n')
skills.add_run('Automation: ').bold = True
skills.add_run('Ansible, Linux Scripting, Python\n')
skills.add_run('DevOps Tools: ').bold = True
skills.add_run('JIRA, GitHub, Argo\n')
skills.add_run('Monitoring: ').bold = True
skills.add_run('SolarWinds, WhatsUp Gold\n')
skills.add_run('Hardware: ').bold = True
skills.add_run('Cisco, Juniper, Arista, Nokia, HP, Dell\n')
skills.add_run('Telecom Tools: ').bold = True
skills.add_run('CLIPS, M6, CRM, IPAM, ORION\n')
skills.add_run('Protocols: ').bold = True
skills.add_run('TCP/IP, MPLS, VLAN, VPN, NAT, DNS, RADIUS\n')
skills.add_run('Security: ').bold = True
skills.add_run('Firewall Management, SSL/TLS, DDoS Mitigation\n')

# Add a horizontal line
add_horizontal_line(doc)

# Add Professional Experience
doc.add_heading('Professional Experience', level=2)

# Vodafone Idea Ltd
doc.add_heading('Vodafone Idea Ltd, Hyderabad', level=3)
doc.add_paragraph('AGM (Telco Cloud DC Fabric Architect)    Mar 2023 - Present')
vodafone_duties = doc.add_paragraph()
vodafone_duties.add_run('• ').bold = True
vodafone_duties.add_run(
    'Led the design and deployment of telco cloud infrastructure across PAN India, leveraging multi-vendor technologies including Cisco, Juniper, Extreme, HP, and Dell.\n'
)
vodafone_duties.add_run('• ').bold = True
vodafone_duties.add_run(
    'Managed virtualization environments using Red Hat OpenStack and Nokia CBIS.\n'
)
vodafone_duties.add_run('• ').bold = True
vodafone_duties.add_run(
    'Authored and implemented change management processes (MOP) for routing, switching, and security in a live production environment.\n'
)
vodafone_duties.add_run('• ').bold = True
vodafone_duties.add_run(
    'Oversaw HLD and LLD validation for data center projects, ensuring alignment with business objectives.\n'
)
vodafone_duties.add_run('• ').bold = True
vodafone_duties.add_run(
    'Specialized in Arista Cloud Vision, Nokia Nuage, and Cisco APIC for SDN integration.\n'
)

# Add a horizontal line
add_horizontal_line(doc)

# Tata Consultancy Services
doc.add_heading('Tata Consultancy Services, Hyderabad', level=3)
doc.add_paragraph('Network Cloud Engineer    Jul 2017 - Mar 2023')
tcs_duties = doc.add_paragraph()
tcs_duties.add_run('• ').bold = True
tcs_duties.add_run(
    'Delivered end-to-end virtualization solutions, including VMware infrastructure and Red Hat OpenShift architecture.\n'
)
tcs_duties.add_run('• ').bold = True
tcs_duties.add_run(
    'Designed and deployed data center networks using Spine-Leaf topology; managed Juniper, HP, and Extreme switches.\n'
)
tcs_duties.add_run('• ').bold = True
tcs_duties.add_run(
    'Developed automation scripts for data center tasks, improving efficiency by 30%.\n'
)
tcs_duties.add_run('• ').bold = True
tcs_duties.add_run(
    'Configured and managed server environments, including OS installations and VM provisioning.\n'
)
tcs_duties.add_run('• ').bold = True
tcs_duties.add_run(
    'Provided DNS and IPAM services, ensuring seamless network integration.\n'
)

# Add a horizontal line
add_horizontal_line(doc)

# Comcast
doc.add_heading('Comcast, Gandhinagar', level=3)
doc.add_paragraph('Sr Network Engineer (SME)    Jul 2016 - Jul 2017')
comcast_duties = doc.add_paragraph()
comcast_duties.add_run('• ').bold = True
comcast_duties.add_run(
    'Designed and provisioned complex network solutions, supporting global products like IP Transit, MPLS, and VPLS.\n'
)
comcast_duties.add_run('• ').bold = True
comcast_duties.add_run(
    'Managed and troubleshooted high-availability network services, including BGP, OSPF, and QoS.\n'
)
comcast_duties.add_run('• ').bold = True
comcast_duties.add_run(
    'Coordinated with business leaders to align technical designs with strategic objectives.\n'
)

# Add a horizontal line
add_horizontal_line(doc)

# Bharti Airtel Ltd
doc.add_heading('Bharti Airtel Ltd, Ahmedabad', level=3)
doc.add_paragraph('Network Engineer    Sept 2016 - Jul 2017')
airtel_duties = doc.add_paragraph()
airtel_duties.add_run('• ').bold = True
airtel_duties.add_run(
    'Configured and supported MPLS VPNs, Layer 3 & Layer 2 services.\n'
)
airtel_duties.add_run('• ').bold = True
airtel_duties.add_run(
    'Provided enterprise network solutions, collaborating with internal teams and external stakeholders.\n'
)

# Add a horizontal line
add_horizontal_line(doc)

# Tata Teleservices Ltd
doc.add_heading('Tata Teleservices Ltd, Ahmedabad', level=3)
doc.add_paragraph('NOC Executive    May 2015 - Sept 2016')
tata_duties = doc.add_paragraph()
tata_duties.add_run('• ').bold = True
tata_duties.add_run(
    'Monitored and managed broadband network operations, ensuring high uptime and performance.\n'
)
tata_duties.add_run('• ').bold = True
tata_duties.add_run(
    'Led a team of 40 engineers, coordinating field and fiber teams for critical issue resolution.\n'
)

# Add a horizontal line
add_horizontal_line(doc)

# Add Education
doc.add_heading('Education', level=2)
doc.add_paragraph('Bachelor of Engineering in Electronics and Communication')
doc.add_paragraph('Gujarat Technological University    2015')
doc.add_paragraph('CGPA: 7.1')
doc.add_paragraph()
doc.add_paragraph('Diploma in Engineering in Electronics and Communication')
doc.add_paragraph('Gujarat Technological University    2011')
doc.add_paragraph('CGPA: 8.7')

# Add a horizontal line
add_horizontal_line(doc)

# Add Certifications
doc.add_heading('Certifications', level=2)
certifications = doc.add_paragraph()
certifications.add_run('• Extreme Certified EDGE DATA CENTER SOLUTION ASSOCIATE\n')
certifications.add_run('• Fortinet Certified NSE1, NSE2\n')
certifications.add_run('• Redhat DevOps Cultural Training Certification\n')

# Add a horizontal line
add_horizontal_line(doc)

# Add Personal Details
doc.add_heading('Personal Details', level=2)
personal_details = doc.add_paragraph()
personal_details.add_run('Date of Birth: ').bold = True
personal_details.add_run('22nd May 1991\n')
personal_details.add_run('Languages: ').bold = True
personal_details.add_run('English, Hindi, Gujarati\n')
personal_details.add_run('Nationality: ').bold = True
personal_details.add_run('Indian\n')
personal_details.add_run('Passport: ').bold = True
personal_details.add_run('Yes\n')

# Save the document
doc_path = "/Users/harishkumarpillai"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from docx import Document
#       3 # Create a new Document
#       4 doc = Document()
#
# ModuleNotFoundError: No module named 'docx'

# %%
# !pip3 install docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 846.7 kB/s eta 0:00:00 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached lxml-5.2.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Using cached pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
# Using cached lxml-5.2.2-cp312-cp312-macosx_10_9_universal2.whl (8.2 MB)
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53895 sha256=26fac534d7c8cc83cc896d2ebe12574fc70435af35a7b1aac1fd6a77f4c07199
#   Stored in directory: /Users/harishkumarpillai/Library/Caches/pip/wheels/f3/ba/dd/43ed5f165600f41deddeb1e382c56ffc1067c09ec5bd705f39
# Successfully built docx
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
